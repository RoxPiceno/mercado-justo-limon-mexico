# %% [markdown]
# # 🍋 Mercado Justo — Estrategia de Mercadotecnia Digital
# > **Universidad Rosario Castellanos** | Materia: Mercadotecnia Digital | Prof. Mario Popoca
# > **Equipo:** Alberto (regresión) · Gretel (Markov+ARIMA) · Rox (ML completo) · Axel (IO)
# > **Proyecto:** Análisis y predicción de precios de limón en México
#
# ---
# Este notebook integra la estrategia de mercadotecnia digital de la plataforma **Mercado Justo**, construida sobre los hallazgos del análisis de datos (SARIMA, Prophet, LSTM, K-means, DBSCAN, Apriori, Montecarlo).
#
# **Estructura:**
# 1. Tipos de mercado del productor de limón
# 2. Análisis PESTEL
# 3. Segmentación de clientes
# 4. Mercado meta
# 5. Competencia directa e indirecta
# 6. Propuesta de valor
# 7. Estrategia 4P's y 4C's
# 8. Canales digitales
# 9. KPIs de éxito
# 10. Investigación de mercado — encuesta

# %%
# @title
from IPython.display import display, HTML

# ─── Estilos globales compartidos por todas las secciones ───────────────────
ESTILOS = """
<style>
.mj { font-family: 'Segoe UI', sans-serif; max-width: 860px; margin: 0 auto; color: #1a1a1a; }
.mj-hero { background: #EAF3DE; border-left: 5px solid #639922; border-radius: 8px;
           padding: 1.2rem 1.5rem; margin-bottom: 1.2rem; }
.mj-hero h2 { margin: 0 0 4px; color: #3B6D11; font-size: 1.3rem; }
.mj-hero p  { margin: 0; color: #27500A; font-size: 0.88rem; }
.sec { background: #fff; border: 1px solid #e0e0e0; border-radius: 10px;
       padding: 1.2rem 1.4rem; margin-bottom: 1rem; }
.sec h3 { margin: 0 0 0.7rem; font-size: 1rem; color: #3B6D11; }
.sec ul  { margin: 0.3rem 0 0 1.1rem; padding: 0; }
.sec li  { margin-bottom: 0.25rem; font-size: 0.9rem; line-height: 1.5; }
.sec p   { font-size: 0.9rem; margin: 0.3rem 0; line-height: 1.55; }
.grid2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
.grid3 { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
.grid4 { display: grid; grid-template-columns: 1fr 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
.metric { background: #f5f5f5; border-radius: 8px; padding: 0.8rem; text-align: center; }
.metric .val { font-size: 1.5rem; font-weight: 600; color: #3B6D11; }
.metric .lbl { font-size: 0.75rem; color: #666; margin-top: 2px; }
.tag { display: inline-block; padding: 2px 9px; border-radius: 20px; font-size: 0.78rem;
       font-weight: 500; margin: 2px; }
.tg  { background: #EAF3DE; color: #3B6D11; }
.ta  { background: #FAEEDA; color: #BA7517; }
.tc  { background: #FAECE7; color: #993C1D; }
.tt  { background: #E1F5EE; color: #0F6E56; }
.oport { background: #EAF3DE; border-left: 3px solid #639922; padding: 0.5rem 0.8rem;
          border-radius: 0 6px 6px 0; margin: 4px 0; font-size: 0.88rem; color: #27500A; }
.amena { background: #FAECE7; border-left: 3px solid #993C1D; padding: 0.5rem 0.8rem;
          border-radius: 0 6px 6px 0; margin: 4px 0; font-size: 0.88rem; color: #993C1D; }
.rule  { background: #FAEEDA; border: 1px solid #FAC775; border-radius: 8px;
          padding: 0.7rem 1rem; font-size: 0.88rem; color: #854F0B; font-weight: 500;
          margin-bottom: 0.8rem; }
.kpi-row { display: flex; justify-content: space-between; align-items: center;
            padding: 0.55rem 0; border-bottom: 1px solid #f0f0f0; font-size: 0.88rem; }
.kpi-row:last-child { border-bottom: none; }
.kpi-target { font-weight: 600; color: #3B6D11; }
.kpi-meta   { font-size: 0.78rem; color: #888; }
.pv-row { display: flex; gap: 10px; padding: 0.65rem 0;
           border-bottom: 1px solid #f0f0f0; font-size: 0.88rem; line-height: 1.5; }
.pv-row:last-child { border-bottom: none; }
.pv-icon { font-size: 1.1rem; flex-shrink: 0; margin-top: 2px; }
table.comp { width: 100%; border-collapse: collapse; font-size: 0.86rem; }
table.comp th { background: #f5f5f5; padding: 0.45rem 0.7rem; text-align: left;
                border-bottom: 2px solid #ddd; font-weight: 600; }
table.comp td { padding: 0.5rem 0.7rem; border-bottom: 1px solid #eee; vertical-align: top; }
.enc-q { background: #f9f9f9; border-radius: 6px; padding: 0.6rem 0.9rem;
          margin-bottom: 0.45rem; font-size: 0.88rem; line-height: 1.5; }
.enc-q .qn { font-weight: 600; color: #639922; margin-right: 4px; }
.p4card { background: #fff; border: 1px solid #e0e0e0; border-radius: 8px;
           padding: 0.9rem 1rem; }
.p4letter { font-size: 2rem; font-weight: 700; color: #C0DD97; line-height: 1; margin-bottom: 4px; }
.p4name   { font-size: 0.95rem; font-weight: 600; margin-bottom: 0.4rem; }
.p4items  { font-size: 0.84rem; color: #444; line-height: 1.55; }
.p4card.c { border-color: #9FE1CB; }
.canal-row { display: flex; gap: 10px; padding: 0.65rem 0;
              border-bottom: 1px solid #f0f0f0; align-items: flex-start; }
.canal-row:last-child { border-bottom: none; }
.canal-icon { width: 32px; height: 32px; border-radius: 6px; background: #EAF3DE;
               display: flex; align-items: center; justify-content: center;
               flex-shrink: 0; font-size: 1rem; }
.canal-name { font-weight: 600; font-size: 0.9rem; }
.canal-why  { font-size: 0.82rem; color: #555; margin-top: 2px; line-height: 1.4; }
.highlight  { background: #EAF3DE; border-radius: 8px; padding: 0.9rem 1.1rem;
               border: 1px solid #9FE1CB; font-size: 1rem; color: #3B6D11;
               font-weight: 500; line-height: 1.5; margin-bottom: 0.8rem; }
.sec-num { font-size: 0.75rem; font-weight: 600; letter-spacing: 0.08em;
            text-transform: uppercase; color: #639922; margin-bottom: 2px; }
.sec-title { font-size: 1.15rem; font-weight: 600; color: #1a1a1a; margin-bottom: 0.3rem; }
.sec-desc  { font-size: 0.88rem; color: #555; margin-bottom: 1rem; line-height: 1.5; }
</style>
"""

display(HTML(ESTILOS + '<div class="mj"><div class="mj-hero"><h2>🍋 Mercado Justo — Mercadotecnia Digital</h2><p>Universidad Rosario Castellanos &nbsp;|&nbsp; Prof. Mario Popoca &nbsp;|&nbsp; Alberto · Gretel · Rox · Axel</p></div></div>'))
print('✅ Estilos cargados. Ejecuta las celdas siguientes para ver cada sección.')
# Out:
# <style>
# .mj { font-family: 'Segoe UI', sans-serif; max-width: 860px; margin: 0 auto; color: #1a1a1a; }
# .mj-hero { background: #EAF3DE; border-left: 5px solid #639922; border-radius: 8px;
#            padding: 1.2rem 1.5rem; margin-bottom: 1.2rem; }
# .mj-hero h2 { margin: 0 0 4px; color: #3B6D11; font-size: 1.3rem; }
# .mj-hero p  { margin: 0; color: #27500A; font-size: 0.88rem; }
# .sec { background: #fff; border: 1px solid #e0e0e0; border-radius: 10px;
#        padding: 1.2rem 1.4rem; margin-bottom: 1rem; }
# .sec h3 { margin: 0 0 0.7rem; font-size: 1rem; color: #3B6D11; }
# .sec ul  { margin: 0.3rem 0 0 1.1rem; padding: 0; }
# .sec li  { margin-bottom: 0.25rem; font-size: 0.9rem; line-height: 1.5; }
# .sec p   { font-size: 0.9rem; margin: 0.3rem 0; line-height: 1.55; }
# .grid2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# .grid3 { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# ...

# %% [markdown]
# ---
# ## Sección 1 — Tipos de mercado del productor de limón

# %%
# @title
s1 = """
<div class='mj'>
  <div class='sec-num'>Sección 01</div>
  <div class='sec-title'>Tipos de mercado del productor de limón</div>
  <div class='sec-desc'>El productor opera simultáneamente en múltiples mercados con dinámicas distintas.
  Nuestro análisis revela comportamientos diferenciados según variedad.</div>

  <div class='rule'>📊 Regla Apriori más poderosa: tipo_cambio_bajo + verano → precio_bajo
  (confianza 100%, lift 4.26x)</div>

  <div class='grid2'>
    <div class='sec'>
      <h3>🍋 Limón mexicano — Mercado de demanda</h3>
      <span class='tag tt'>Demanda</span>
      <ul>
        <li>Variable dominante: <strong>IGAE</strong></li>
        <li>Precio sube con actividad económica nacional</li>
        <li>Sensible al ciclo económico</li>
        <li>Menor elasticidad climática que el persa</li>
      </ul>
    </div>
    <div class='sec'>
      <h3>💧 Limón persa — Mercado de oferta</h3>
      <span class='tag ta'>Oferta</span>
      <ul>
        <li>Variable dominante: <strong>lluvia</strong></li>
        <li>Precio responde al volumen cosechado</li>
        <li>Alta estacionalidad productiva</li>
        <li>Oportunidad en temporadas de sequía moderada</li>
      </ul>
    </div>
  </div>

  <div class='grid3'>
    <div class='metric'><div class='val'>42.7%</div>
      <div class='lbl'>del precio mayorista recibe el productor</div></div>
    <div class='metric'><div class='val'>14 años</div>
      <div class='lbl'>con brecha de intermediación estable</div></div>
    <div class='metric'><div class='val'>&gt;70%</div>
      <div class='lbl'>producción: Michoacán + Veracruz</div></div>
  </div>

  <div class='sec'>
    <h3>📅 Mercado por temporada</h3>
    <ul>
      <li><span class='tag tg'>Feb–May</span> Ventana óptima de venta — precios más altos del año</li>
      <li><span class='tag tc'>Julio</span> Peor mes para vender — coincide con lluvias + tipo de cambio bajo</li>
      <li><span class='tag ta'>20 meses anómalos</span> detectados por DBSCAN: crisis de precios fuera de ciclos normales</li>
    </ul>
  </div>

  <div class='sec'>
    <h3>🏪 Estructura de mercado</h3>
    <ul>
      <li>Competencia imperfecta — el intermediario tiene poder de precio</li>
      <li>Información asimétrica severa: el intermediario conoce precios de destino, el productor no</li>
      <li>Mercado Justo interviene en la asimetría de información, no en la cadena física de distribución</li>
    </ul>
  </div>
</div>
"""
display(HTML(ESTILOS + s1))
# Out:
# <style>
# .mj { font-family: 'Segoe UI', sans-serif; max-width: 860px; margin: 0 auto; color: #1a1a1a; }
# .mj-hero { background: #EAF3DE; border-left: 5px solid #639922; border-radius: 8px;
#            padding: 1.2rem 1.5rem; margin-bottom: 1.2rem; }
# .mj-hero h2 { margin: 0 0 4px; color: #3B6D11; font-size: 1.3rem; }
# .mj-hero p  { margin: 0; color: #27500A; font-size: 0.88rem; }
# .sec { background: #fff; border: 1px solid #e0e0e0; border-radius: 10px;
#        padding: 1.2rem 1.4rem; margin-bottom: 1rem; }
# .sec h3 { margin: 0 0 0.7rem; font-size: 1rem; color: #3B6D11; }
# .sec ul  { margin: 0.3rem 0 0 1.1rem; padding: 0; }
# .sec li  { margin-bottom: 0.25rem; font-size: 0.9rem; line-height: 1.5; }
# .sec p   { font-size: 0.9rem; margin: 0.3rem 0; line-height: 1.55; }
# .grid2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# .grid3 { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# ...

# %% [markdown]
# ---
# ## Sección 2 — Análisis PESTEL

# %%
# @title
s2 = """
<div class='mj'>
  <div class='sec-num'>Sección 02</div>
  <div class='sec-title'>Análisis PESTEL</div>
  <div class='sec-desc'>Factores del macroentorno que condicionan el mercado del limón
  y la viabilidad de la plataforma Mercado Justo.</div>

  <div class='sec'><h3>🏛️ Político</h3>
    <div class='oport'>✅ Programa Agricultura por Contrato (SADER) — abre canales directos productor–comprador</div>
    <div class='oport'>✅ Estrategia Digital Nacional — impulsa conectividad rural</div>
    <div class='amena'>⚠️ Inestabilidad en Michoacán (grupos criminales en zonas productoras)</div>
    <div class='amena'>⚠️ Cambios en subsidios agrícolas con cada administración</div>
  </div>

  <div class='sec'><h3>📈 Económico</h3>
    <div class='oport'>✅ IGAE como variable predictiva — nuestro modelo lo captura y anticipa variaciones</div>
    <div class='oport'>✅ Montecarlo: ingreso esperado $254,368 con portafolio mixto 10t mexicano + 10t persa</div>
    <div class='amena'>⚠️ Volatilidad tipo de cambio (regla tc_bajo + verano → precio_bajo, confianza 100%)</div>
    <div class='amena'>⚠️ Inflación de insumos agrícolas: fertilizantes, diesel</div>
  </div>

  <div class='sec'><h3>👥 Social</h3>
    <div class='oport'>✅ Creciente consciencia sobre comercio justo y economía rural</div>
    <div class='oport'>✅ Adopción de smartphones en zonas rurales supera 60% (ENDUTIH 2023)</div>
    <div class='amena'>⚠️ Brecha digital generacional — productores mayores con baja alfabetización digital</div>
    <div class='amena'>⚠️ Desconfianza histórica hacia tecnología externa al ejido</div>
  </div>

  <div class='sec'><h3>💻 Tecnológico</h3>
    <div class='oport'>✅ SARIMA + Prophet + LSTM ya implementados — ventaja técnica real vs competencia</div>
    <div class='oport'>✅ WhatsApp Business API: notificaciones sin necesidad de app propia</div>
    <div class='amena'>⚠️ Conectividad rural limitada — zonas sin 4G en Michoacán y Veracruz</div>
    <div class='amena'>⚠️ Costo de infraestructura de datos (SNIIM, SIAP, actualización continua)</div>
  </div>

  <div class='sec'><h3>🌿 Ecológico</h3>
    <div class='oport'>✅ Lluvia como variable predictiva del persa — modelo puede alertar cosechas excesivas</div>
    <div class='oport'>✅ Cambio climático aumenta volatilidad = mayor valor de pronósticos precisos</div>
    <div class='amena'>⚠️ Sequías prolongadas estabilizan precios — reducen temporalmente la utilidad del modelo</div>
  </div>

  <div class='sec'><h3>⚖️ Legal</h3>
    <div class='oport'>✅ LFPDPPP: cumplimiento en protección de datos posiciona como plataforma confiable</div>
    <div class='amena'>⚠️ Uso comercial de datos SNIIM/SIAP puede requerir licencias formales</div>
    <div class='amena'>⚠️ Marco legal difuso para plataformas que ofrecen "predicciones" a productores no consumidores</div>
  </div>
</div>
"""
display(HTML(ESTILOS + s2))
# Out:
# <style>
# .mj { font-family: 'Segoe UI', sans-serif; max-width: 860px; margin: 0 auto; color: #1a1a1a; }
# .mj-hero { background: #EAF3DE; border-left: 5px solid #639922; border-radius: 8px;
#            padding: 1.2rem 1.5rem; margin-bottom: 1.2rem; }
# .mj-hero h2 { margin: 0 0 4px; color: #3B6D11; font-size: 1.3rem; }
# .mj-hero p  { margin: 0; color: #27500A; font-size: 0.88rem; }
# .sec { background: #fff; border: 1px solid #e0e0e0; border-radius: 10px;
#        padding: 1.2rem 1.4rem; margin-bottom: 1rem; }
# .sec h3 { margin: 0 0 0.7rem; font-size: 1rem; color: #3B6D11; }
# .sec ul  { margin: 0.3rem 0 0 1.1rem; padding: 0; }
# .sec li  { margin-bottom: 0.25rem; font-size: 0.9rem; line-height: 1.5; }
# .sec p   { font-size: 0.9rem; margin: 0.3rem 0; line-height: 1.55; }
# .grid2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# .grid3 { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# ...

# %% [markdown]
# ---
# ## Sección 3 — Segmentación de clientes

# %%
# @title
s3 = """
<div class='mj'>
  <div class='sec-num'>Sección 03</div>
  <div class='sec-title'>Segmentación de clientes</div>
  <div class='sec-desc'>Mercado Justo tiene tres tipos de usuario con necesidades radicalmente distintas.
  Segmentación geográfica, demográfica y psicográfica.</div>

  <div class='sec'>
    <h3>🚜 Segmento A — Productor primario <span class='tag tg'>Usuario principal</span> <span class='tag tg'>Gratuito</span></h3>
    <ul>
      <li><strong>Geográfico:</strong> Michoacán (Apatzingán, Tecomán) y Veracruz (Martínez de la Torre, Álamo)</li>
      <li><strong>Demográfico:</strong> 35–65 años, 3–20 ha, ingreso anual $80k–$400k MXN, primaria a bachillerato</li>
      <li><strong>Psicográfico:</strong> Desconfiado del intermediario pero dependiente; decide por WhatsApp y radio;
          valora la palabra de veteranos del rancho</li>
      <li><strong>Conductual:</strong> Vende al mismo coyote de siempre; no compara precios;
          toma decisiones 48–72h antes de cosechar</li>
    </ul>
  </div>

  <div class='sec'>
    <h3>🏬 Segmento B — Intermediario / coyote <span class='tag ta'>Secundario</span> <span class='tag ta'>Potencial premium</span></h3>
    <ul>
      <li><strong>Perfil:</strong> Compra a múltiples productores y vende a empacadoras o mercados de abasto</li>
      <li><strong>Dolor:</strong> Necesita predecir precios para optimizar su margen y reducir mermas</li>
      <li><strong>Oportunidad:</strong> Modelo B2B — suscripción por análisis de zona o variedad específica</li>
      <li><strong>Riesgo:</strong> Si usa la plataforma reduce la asimetría que le da poder — incentivo para ignorarla</li>
    </ul>
  </div>

  <div class='sec'>
    <h3>🎓 Segmento C — Institucional / académico <span class='tag tt'>Aliado</span> <span class='tag tt'>Validador</span></h3>
    <ul>
      <li><strong>Perfil:</strong> SADER, FIRA, universidades agrarias, ONGs de desarrollo rural</li>
      <li><strong>Valor:</strong> Legitiman la plataforma, pueden cofinanciar, abren canales a ejidos</li>
      <li><strong>Conducta:</strong> Requieren reportes formales, datos abiertos y convenios institucionales</li>
    </ul>
  </div>
</div>
"""
display(HTML(ESTILOS + s3))
# Out:
# <style>
# .mj { font-family: 'Segoe UI', sans-serif; max-width: 860px; margin: 0 auto; color: #1a1a1a; }
# .mj-hero { background: #EAF3DE; border-left: 5px solid #639922; border-radius: 8px;
#            padding: 1.2rem 1.5rem; margin-bottom: 1.2rem; }
# .mj-hero h2 { margin: 0 0 4px; color: #3B6D11; font-size: 1.3rem; }
# .mj-hero p  { margin: 0; color: #27500A; font-size: 0.88rem; }
# .sec { background: #fff; border: 1px solid #e0e0e0; border-radius: 10px;
#        padding: 1.2rem 1.4rem; margin-bottom: 1rem; }
# .sec h3 { margin: 0 0 0.7rem; font-size: 1rem; color: #3B6D11; }
# .sec ul  { margin: 0.3rem 0 0 1.1rem; padding: 0; }
# .sec li  { margin-bottom: 0.25rem; font-size: 0.9rem; line-height: 1.5; }
# .sec p   { font-size: 0.9rem; margin: 0.3rem 0; line-height: 1.55; }
# .grid2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# .grid3 { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# ...

# %% [markdown]
# ---
# ## Sección 4 — Mercado meta

# %%
# @title
s4 = """
<div class='mj'>
  <div class='sec-num'>Sección 04</div>
  <div class='sec-title'>Mercado meta</div>
  <div class='sec-desc'>Definición precisa del segmento al que Mercado Justo dirige su estrategia
  de comunicación y producto en la fase de lanzamiento.</div>

  <div class='sec'>
    <h3>🎯 Mercado meta primario</h3>
    <p>Pequeño y mediano productor de limón mexicano en Michoacán, 35–55 años, con acceso a
    smartphone (aunque no nativo digital), que vende a intermediario local y nunca ha comparado
    precios antes de cerrar trato.</p>
    <div class='grid3' style='margin-top:0.8rem;'>
      <div class='metric'><div class='val'>~42k</div>
        <div class='lbl'>productores de limón en México (SIAP)</div></div>
      <div class='metric'><div class='val'>60%</div>
        <div class='lbl'>con smartphone en zona rural (ENDUTIH)</div></div>
      <div class='metric'><div class='val'>~25k</div>
        <div class='lbl'>TAM accesible estimado</div></div>
    </div>
  </div>

  <div class='sec'>
    <h3>❤️ Necesidad que satisface</h3>
    <p>Saber <strong>cuándo vender</strong> y a <strong>qué precio mínimo aceptar</strong>,
    antes de que llegue el comprador al rancho. No necesita entender SARIMA; necesita recibir:<br>
    <em>"Esta semana el precio baja — espera 10 días o negocia sobre $X/kg."</em></p>
  </div>

  <div class='sec'>
    <h3>⏱️ Perfil de comportamiento de compra</h3>
    <ul>
      <li>Ciclo de decisión: 48–72 horas antes de la cosecha</li>
      <li>Canal de confianza: WhatsApp, boca a boca, radio comunitaria</li>
      <li>Disposición a pagar inicial: nula — freemium es el único modelo viable al arranque</li>
      <li>Influenciadores clave: otros productores del ejido, técnico agrónomo del FIRA,
          líder de organización agraria</li>
    </ul>
  </div>

  <div class='sec'>
    <h3>📍 Geografía de arranque</h3>
    <p>Municipios piloto: <strong>Apatzingán y Tecomán</strong> (Michoacán) — mayor concentración
    de producción de limón mexicano y presencia de organizaciones de productores ya articuladas.</p>
  </div>
</div>
"""
display(HTML(ESTILOS + s4))
# Out:
# <style>
# .mj { font-family: 'Segoe UI', sans-serif; max-width: 860px; margin: 0 auto; color: #1a1a1a; }
# .mj-hero { background: #EAF3DE; border-left: 5px solid #639922; border-radius: 8px;
#            padding: 1.2rem 1.5rem; margin-bottom: 1.2rem; }
# .mj-hero h2 { margin: 0 0 4px; color: #3B6D11; font-size: 1.3rem; }
# .mj-hero p  { margin: 0; color: #27500A; font-size: 0.88rem; }
# .sec { background: #fff; border: 1px solid #e0e0e0; border-radius: 10px;
#        padding: 1.2rem 1.4rem; margin-bottom: 1rem; }
# .sec h3 { margin: 0 0 0.7rem; font-size: 1rem; color: #3B6D11; }
# .sec ul  { margin: 0.3rem 0 0 1.1rem; padding: 0; }
# .sec li  { margin-bottom: 0.25rem; font-size: 0.9rem; line-height: 1.5; }
# .sec p   { font-size: 0.9rem; margin: 0.3rem 0; line-height: 1.55; }
# .grid2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# .grid3 { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# ...

# %% [markdown]
# ---
# ## Sección 5 — Competencia directa e indirecta

# %%
# @title
s5 = """
<div class='mj'>
  <div class='sec-num'>Sección 05</div>
  <div class='sec-title'>Competencia directa e indirecta</div>
  <div class='sec-desc'>Mercado Justo no compite con nadie en predicción de precios de limón —
  esa es exactamente la oportunidad. La competencia real es la inercia del productor.</div>

  <div class='sec'>
    <h3>🔵 Competencia directa</h3>
    <table class='comp'>
      <thead><tr><th>Plataforma</th><th>Qué hace</th><th>Diferencia vs Mercado Justo</th></tr></thead>
      <tbody>
        <tr><td><strong>SNIIM (SE)</strong></td>
            <td>Publica precios históricos y del día en mercados mayoristas</td>
            <td>MJ predice el futuro; SNIIM solo reporta el pasado en lenguaje técnico</td></tr>
        <tr><td><strong>Precios del Campo (SADER)</strong></td>
            <td>App gubernamental de precios agrícolas</td>
            <td>Datos en crudo sin interpretación; sin predicción; sin personalización por variedad</td></tr>
        <tr><td><strong>AgroApp / Kubo</strong></td>
            <td>Finanzas y crédito para productores</td>
            <td>No predicen precios de mercado — enfocados en financiamiento rural</td></tr>
      </tbody>
    </table>
  </div>

  <div class='sec'>
    <h3>🟠 Competencia indirecta</h3>
    <ul>
      <li><strong>El intermediario mismo</strong> — comparte información selectiva y sesgada para negociar a la baja</li>
      <li><strong>Grupos de WhatsApp de productores</strong> — precios del día sin validación ni predicción</li>
      <li><strong>Radio agraria local</strong> — precios con retraso y sin desagregación por variedad</li>
      <li><strong>Inercia informacional</strong> — "así siempre ha sido" es el competidor más difícil de vencer</li>
    </ul>
  </div>

  <div class='sec'>
    <h3>🏆 Ventaja competitiva de Mercado Justo</h3>
    <ul>
      <li>Único que modela <strong>dos variedades con lógicas distintas</strong> (demanda vs oferta)</li>
      <li>Modelos ensemble validados: SARIMA + Prophet + LSTM con datos reales SNIIM/SIAP</li>
      <li>Traducción a lenguaje accionable — no da estadísticas, da <em>recomendaciones de timing</em></li>
      <li>Detección de anomalías vía DBSCAN — distingue crisis de variaciones estacionales normales</li>
      <li>484 reglas de asociación Apriori — patrones combinados que ningún competidor identifica</li>
    </ul>
  </div>
</div>
"""
display(HTML(ESTILOS + s5))
# Out:
# <style>
# .mj { font-family: 'Segoe UI', sans-serif; max-width: 860px; margin: 0 auto; color: #1a1a1a; }
# .mj-hero { background: #EAF3DE; border-left: 5px solid #639922; border-radius: 8px;
#            padding: 1.2rem 1.5rem; margin-bottom: 1.2rem; }
# .mj-hero h2 { margin: 0 0 4px; color: #3B6D11; font-size: 1.3rem; }
# .mj-hero p  { margin: 0; color: #27500A; font-size: 0.88rem; }
# .sec { background: #fff; border: 1px solid #e0e0e0; border-radius: 10px;
#        padding: 1.2rem 1.4rem; margin-bottom: 1rem; }
# .sec h3 { margin: 0 0 0.7rem; font-size: 1rem; color: #3B6D11; }
# .sec ul  { margin: 0.3rem 0 0 1.1rem; padding: 0; }
# .sec li  { margin-bottom: 0.25rem; font-size: 0.9rem; line-height: 1.5; }
# .sec p   { font-size: 0.9rem; margin: 0.3rem 0; line-height: 1.55; }
# .grid2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# .grid3 { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# ...

# %% [markdown]
# ---
# ## Sección 6 — Propuesta de valor

# %%
# @title
s6 = """
<div class='mj'>
  <div class='sec-num'>Sección 06</div>
  <div class='sec-title'>Propuesta de valor</div>
  <div class='sec-desc'>El núcleo de por qué Mercado Justo existe y qué promete entregar,
  en términos que el productor entiende y el académico puede defender.</div>

  <div class='highlight'>
    "Mercado Justo te dice cuándo vender tu limón y a qué precio mínimo aceptar
    — antes de que llegue el comprador."
  </div>

  <div class='sec'>
    <div class='pv-row'><div class='pv-icon'>👁️</div>
      <div><strong>Visibilidad de precios futuros.</strong> El productor obtiene pronósticos a 2–4 semanas
      basados en IGAE, lluvia, tipo de cambio y estacionalidad — las mismas variables que
      el intermediario ya conoce.</div></div>
    <div class='pv-row'><div class='pv-icon'>⏱️</div>
      <div><strong>Timing de venta.</strong> Alertas semanales que indican si conviene vender ahora
      o esperar, con base en la ventana feb–mayo vs la caída de julio.</div></div>
    <div class='pv-row'><div class='pv-icon'>🚨</div>
      <div><strong>Detección de crisis.</strong> El modelo DBSCAN identificó 20 meses anómalos.
      Mercado Justo alerta cuando el patrón actual se asemeja a esos episodios históricos.</div></div>
    <div class='pv-row'><div class='pv-icon'>🗣️</div>
      <div><strong>Lenguaje accesible.</strong> No tablas de datos — mensajes como:
      <em>"Esta semana en Tecomán: precio del persa baja. Si puedes esperar 2 semanas,
      el modelo estima $X/kg adicional."</em></div></div>
    <div class='pv-row'><div class='pv-icon'>🛡️</div>
      <div><strong>Sin compromiso de compra.</strong> Mercado Justo es información, no intermediación.
      No reemplaza al comprador — reduce el poder de negociación asimétrico del intermediario.</div></div>
  </div>
</div>
"""
display(HTML(ESTILOS + s6))
# Out:
# <style>
# .mj { font-family: 'Segoe UI', sans-serif; max-width: 860px; margin: 0 auto; color: #1a1a1a; }
# .mj-hero { background: #EAF3DE; border-left: 5px solid #639922; border-radius: 8px;
#            padding: 1.2rem 1.5rem; margin-bottom: 1.2rem; }
# .mj-hero h2 { margin: 0 0 4px; color: #3B6D11; font-size: 1.3rem; }
# .mj-hero p  { margin: 0; color: #27500A; font-size: 0.88rem; }
# .sec { background: #fff; border: 1px solid #e0e0e0; border-radius: 10px;
#        padding: 1.2rem 1.4rem; margin-bottom: 1rem; }
# .sec h3 { margin: 0 0 0.7rem; font-size: 1rem; color: #3B6D11; }
# .sec ul  { margin: 0.3rem 0 0 1.1rem; padding: 0; }
# .sec li  { margin-bottom: 0.25rem; font-size: 0.9rem; line-height: 1.5; }
# .sec p   { font-size: 0.9rem; margin: 0.3rem 0; line-height: 1.55; }
# .grid2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# .grid3 { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# ...

# %% [markdown]
# ---
# ## Sección 7 — Estrategia 4P's y 4C's

# %%
# @title
s7 = """
<div class='mj'>
  <div class='sec-num'>Sección 07</div>
  <div class='sec-title'>Estrategia 4P's y 4C's</div>
  <div class='sec-desc'>Marco clásico reinterpretado desde la perspectiva del productor como cliente.
  Las 4C's complementan poniendo al usuario al centro.</div>

  <p style='font-size:0.78rem;font-weight:600;color:#888;text-transform:uppercase;
     letter-spacing:0.07em;margin-bottom:0.5rem;'>4P'S — Perspectiva de la empresa</p>
  <div class='grid2'>
    <div class='p4card'>
      <div class='p4letter'>P</div>
      <div class='p4name'>Producto</div>
      <div class='p4items'>Plataforma digital de pronóstico de precios.<br>
        MVP: bot de WhatsApp con alertas semanales por municipio y variedad.<br>
        V2: dashboard web con visualización de tendencias.<br>
        V3: API para integradores institucionales (FIRA, SADER).</div>
    </div>
    <div class='p4card'>
      <div class='p4letter'>P</div>
      <div class='p4name'>Precio</div>
      <div class='p4items'>Freemium para productor individual — alertas básicas sin costo.<br>
        Premium $99 MXN/mes: pronóstico a 4 semanas, comparativa por municipio,
        simulación de escenarios.<br>
        B2B institucional: cotización por convenio.</div>
    </div>
    <div class='p4card'>
      <div class='p4letter'>P</div>
      <div class='p4name'>Plaza</div>
      <div class='p4items'>Canal principal: WhatsApp (sin descarga de app).<br>
        Canal secundario: sitio web responsive.<br>
        Distribución física: alianza con técnicos FIRA y promotores ejidales
        en Apatzingán y Tecomán.</div>
    </div>
    <div class='p4card'>
      <div class='p4letter'>P</div>
      <div class='p4name'>Promoción</div>
      <div class='p4items'>Demostraciones en asambleas ejidales.<br>
        Radio comunitaria (cuñas de 30 seg).<br>
        Facebook orgánico en grupos de agricultores.<br>
        Referidos: "invita a un productor y recibe 1 mes premium."</div>
    </div>
  </div>

  <p style='font-size:0.78rem;font-weight:600;color:#888;text-transform:uppercase;
     letter-spacing:0.07em;margin:0.5rem 0;'>4C'S — Perspectiva del cliente</p>
  <div class='grid2'>
    <div class='p4card c'>
      <div class='p4letter' style='color:#5DCAA5;'>C</div>
      <div class='p4name'>Cliente (valor)</div>
      <div class='p4items'>No vende software — vende capacidad de negociación.
        El productor gana poder frente al intermediario sin entender el modelo.
        Valor tangible: potencial de $X/kg adicional en cada venta.</div>
    </div>
    <div class='p4card c'>
      <div class='p4letter' style='color:#5DCAA5;'>C</div>
      <div class='p4name'>Costo</div>
      <div class='p4items'>Costo real: tiempo de aprendizaje + datos móviles.
        Reducción de fricción: bot de WhatsApp sin descarga ni registro formal
        — basta enviar "HOLA" al número.</div>
    </div>
    <div class='p4card c'>
      <div class='p4letter' style='color:#5DCAA5;'>C</div>
      <div class='p4name'>Conveniencia</div>
      <div class='p4items'>La alerta llega al productor — él no busca el dato.
        Formato: texto plano sin tecnicismos.
        Sin internet permanente: el mensaje llega cuando hay señal.</div>
    </div>
    <div class='p4card c'>
      <div class='p4letter' style='color:#5DCAA5;'>C</div>
      <div class='p4name'>Comunicación</div>
      <div class='p4items'>Tono: directo, confiable, sin tecnicismos.
        Voz: como si el técnico agrónomo del ejido te mandara un WhatsApp.
        Contenido: casos reales de productores que mejoraron su precio.</div>
    </div>
  </div>
</div>
"""
display(HTML(ESTILOS + s7))
# Out:
# <style>
# .mj { font-family: 'Segoe UI', sans-serif; max-width: 860px; margin: 0 auto; color: #1a1a1a; }
# .mj-hero { background: #EAF3DE; border-left: 5px solid #639922; border-radius: 8px;
#            padding: 1.2rem 1.5rem; margin-bottom: 1.2rem; }
# .mj-hero h2 { margin: 0 0 4px; color: #3B6D11; font-size: 1.3rem; }
# .mj-hero p  { margin: 0; color: #27500A; font-size: 0.88rem; }
# .sec { background: #fff; border: 1px solid #e0e0e0; border-radius: 10px;
#        padding: 1.2rem 1.4rem; margin-bottom: 1rem; }
# .sec h3 { margin: 0 0 0.7rem; font-size: 1rem; color: #3B6D11; }
# .sec ul  { margin: 0.3rem 0 0 1.1rem; padding: 0; }
# .sec li  { margin-bottom: 0.25rem; font-size: 0.9rem; line-height: 1.5; }
# .sec p   { font-size: 0.9rem; margin: 0.3rem 0; line-height: 1.55; }
# .grid2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# .grid3 { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# ...

# %% [markdown]
# ---
# ## Sección 8 — Canales digitales

# %%
# @title
s8 = """
<div class='mj'>
  <div class='sec-num'>Sección 08</div>
  <div class='sec-title'>Canales digitales</div>
  <div class='sec-desc'>La selección de canales responde a la realidad del productor rural,
  no a las mejores prácticas del marketing urbano.</div>

  <div class='sec'>
    <div class='canal-row'>
      <div class='canal-icon'>💬</div>
      <div><div style='display:flex;justify-content:space-between;align-items:center;'>
        <div class='canal-name'>WhatsApp Business</div>
        <span class='tag tg'>Prioridad 1</span></div>
        <div class='canal-why'>Canal dominante en zonas rurales. Sin barrera de entrada.
        Chatbot con menú por variedad y municipio. Tasa de apertura &gt;90%.
        No requiere app adicional.</div></div>
    </div>
    <div class='canal-row'>
      <div class='canal-icon'>📘</div>
      <div><div style='display:flex;justify-content:space-between;align-items:center;'>
        <div class='canal-name'>Facebook (orgánico + grupos)</div>
        <span class='tag tg'>Prioridad 2</span></div>
        <div class='canal-why'>Red social dominante en productores 35–60 años en Michoacán/Veracruz.
        Grupos "Productores de limón" ya existen con miles de miembros.
        Publicaciones de pronóstico semanal con imagen simple.</div></div>
    </div>
    <div class='canal-row'>
      <div class='canal-icon'>🌐</div>
      <div><div style='display:flex;justify-content:space-between;align-items:center;'>
        <div class='canal-name'>Sitio web (SEO local)</div>
        <span class='tag ta'>Prioridad 3</span></div>
        <div class='canal-why'>Landing optimizada para búsquedas "precio limón hoy Michoacán".
        Dashboard de pronósticos embebido. SEO de cola larga:
        "precio limón persa Veracruz semana".</div></div>
    </div>
    <div class='canal-row'>
      <div class='canal-icon'>📻</div>
      <div><div style='display:flex;justify-content:space-between;align-items:center;'>
        <div class='canal-name'>Radio comunitaria (canal phygital)</div>
        <span class='tag ta'>Prioridad 4</span></div>
        <div class='canal-why'>Máxima penetración en zonas sin cobertura digital constante.
        Cuña de 30 seg con el pronóstico de la semana + invitación a unirse al WhatsApp.
        Refuerzo de credibilidad institucional.</div></div>
    </div>
    <div class='canal-row'>
      <div class='canal-icon'>📧</div>
      <div><div style='display:flex;justify-content:space-between;align-items:center;'>
        <div class='canal-name'>Email (segmento institucional)</div>
        <span class='tag tt'>B2B</span></div>
        <div class='canal-why'>Newsletter mensual con informe técnico de tendencias para
        SADER, FIRA, universidades agrarias. Posiciona a Mercado Justo como
        fuente de datos confiable ante tomadores de decisión.</div></div>
    </div>
  </div>

  <div class='sec'>
    <h3>🔍 Palabras clave SEO/SEM</h3>
    <div>
      <span class='tag tg'>precio limón hoy</span>
      <span class='tag tg'>precio limón mexicano Michoacán</span>
      <span class='tag tg'>precio limón persa Veracruz</span>
      <span class='tag ta'>cuándo vender limón</span>
      <span class='tag ta'>mercado de limón México</span>
      <span class='tag tt'>predicción precio cítricos México</span>
    </div>
    <p style='margin-top:0.6rem;font-size:0.83rem;color:#555;'>SEM solo en temporada de alta
    decisión (enero–abril) con presupuesto acotado $3–5k MXN/mes dirigido a municipios piloto.</p>
  </div>
</div>
"""
display(HTML(ESTILOS + s8))
# Out:
# <style>
# .mj { font-family: 'Segoe UI', sans-serif; max-width: 860px; margin: 0 auto; color: #1a1a1a; }
# .mj-hero { background: #EAF3DE; border-left: 5px solid #639922; border-radius: 8px;
#            padding: 1.2rem 1.5rem; margin-bottom: 1.2rem; }
# .mj-hero h2 { margin: 0 0 4px; color: #3B6D11; font-size: 1.3rem; }
# .mj-hero p  { margin: 0; color: #27500A; font-size: 0.88rem; }
# .sec { background: #fff; border: 1px solid #e0e0e0; border-radius: 10px;
#        padding: 1.2rem 1.4rem; margin-bottom: 1rem; }
# .sec h3 { margin: 0 0 0.7rem; font-size: 1rem; color: #3B6D11; }
# .sec ul  { margin: 0.3rem 0 0 1.1rem; padding: 0; }
# .sec li  { margin-bottom: 0.25rem; font-size: 0.9rem; line-height: 1.5; }
# .sec p   { font-size: 0.9rem; margin: 0.3rem 0; line-height: 1.55; }
# .grid2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# .grid3 { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# ...

# %% [markdown]
# ---
# ## Sección 9 — KPIs de éxito

# %%
# @title
s9 = """
<div class='mj'>
  <div class='sec-num'>Sección 09</div>
  <div class='sec-title'>KPIs de éxito</div>
  <div class='sec-desc'>Indicadores en tres horizontes: adopción (usuarios),
  engagement (uso real) e impacto (cambio económico en el productor).</div>

  <div class='sec'>
    <h3>👥 KPIs de adopción (mes 1–6)</h3>
    <div class='kpi-row'><span>Productores registrados en WhatsApp bot</span>
      <div><div class='kpi-target'>≥ 500</div><div class='kpi-meta'>al mes 6</div></div></div>
    <div class='kpi-row'><span>Municipios activos</span>
      <div><div class='kpi-target'>≥ 5</div><div class='kpi-meta'>Michoacán y Veracruz</div></div></div>
    <div class='kpi-row'><span>Tasa de retención (semana 4)</span>
      <div><div class='kpi-target'>≥ 60%</div><div class='kpi-meta'>siguen usando el servicio</div></div></div>
    <div class='kpi-row'><span>Seguidores en grupos de Facebook</span>
      <div><div class='kpi-target'>≥ 1,000</div><div class='kpi-meta'>al mes 3</div></div></div>
    <div class='kpi-row'><span>Alcance orgánico semanal (Facebook)</span>
      <div><div class='kpi-target'>≥ 3,000</div><div class='kpi-meta'>personas únicas</div></div></div>
  </div>

  <div class='sec'>
    <h3>📊 KPIs de engagement (mes 3–12)</h3>
    <div class='kpi-row'><span>Tasa de apertura de mensajes WhatsApp</span>
      <div><div class='kpi-target'>≥ 80%</div><div class='kpi-meta'>benchmark email: ~22%</div></div></div>
    <div class='kpi-row'><span>Consultas activas al bot / semana</span>
      <div><div class='kpi-target'>≥ 3 por usuario</div><div class='kpi-meta'>en semana de cosecha</div></div></div>
    <div class='kpi-row'><span>NPS (Net Promoter Score)</span>
      <div><div class='kpi-target'>≥ +40</div><div class='kpi-meta'>encuesta mensual</div></div></div>
    <div class='kpi-row'><span>Tasa de referidos</span>
      <div><div class='kpi-target'>≥ 20%</div><div class='kpi-meta'>nuevos usuarios por boca a boca</div></div></div>
    <div class='kpi-row'><span>Visitas al sitio web / mes</span>
      <div><div class='kpi-target'>≥ 2,000</div><div class='kpi-meta'>al mes 6</div></div></div>
  </div>

  <div class='sec'>
    <h3>💰 KPIs de impacto económico (mes 6–18)</h3>
    <div class='kpi-row'><span>Usuarios que reportan haber negociado mejor precio</span>
      <div><div class='kpi-target'>≥ 35%</div><div class='kpi-meta'>encuesta post-cosecha</div></div></div>
    <div class='kpi-row'><span>Diferencia de precio obtenido vs semana sin alerta</span>
      <div><div class='kpi-target'>≥ $0.30/kg</div><div class='kpi-meta'>medición longitudinal piloto</div></div></div>
    <div class='kpi-row'><span>Ingreso adicional promedio por productor/ciclo</span>
      <div><div class='kpi-target'>≥ $3,000 MXN</div><div class='kpi-meta'>estimación con 10t promedio</div></div></div>
    <div class='kpi-row'><span>Conversión a plan premium</span>
      <div><div class='kpi-target'>≥ 5%</div><div class='kpi-meta'>de usuarios activos al mes 12</div></div></div>
  </div>

  <div class='sec'>
    <h3>🤖 KPIs del modelo predictivo</h3>
    <div class='kpi-row'><span>Precisión direccional del pronóstico (sube/baja)</span>
      <div><div class='kpi-target'>≥ 70%</div><div class='kpi-meta'>validación vs datos reales</div></div></div>
    <div class='kpi-row'><span>MAPE (Error Porcentual Absoluto Medio)</span>
      <div><div class='kpi-target'>≤ 15%</div><div class='kpi-meta'>horizonte de 2 semanas</div></div></div>
    <div class='kpi-row'><span>Cobertura de alertas de anomalía</span>
      <div><div class='kpi-target'>≥ 80%</div><div class='kpi-meta'>eventos tipo DBSCAN detectados</div></div></div>
  </div>
</div>
"""
display(HTML(ESTILOS + s9))
# Out:
# <style>
# .mj { font-family: 'Segoe UI', sans-serif; max-width: 860px; margin: 0 auto; color: #1a1a1a; }
# .mj-hero { background: #EAF3DE; border-left: 5px solid #639922; border-radius: 8px;
#            padding: 1.2rem 1.5rem; margin-bottom: 1.2rem; }
# .mj-hero h2 { margin: 0 0 4px; color: #3B6D11; font-size: 1.3rem; }
# .mj-hero p  { margin: 0; color: #27500A; font-size: 0.88rem; }
# .sec { background: #fff; border: 1px solid #e0e0e0; border-radius: 10px;
#        padding: 1.2rem 1.4rem; margin-bottom: 1rem; }
# .sec h3 { margin: 0 0 0.7rem; font-size: 1rem; color: #3B6D11; }
# .sec ul  { margin: 0.3rem 0 0 1.1rem; padding: 0; }
# .sec li  { margin-bottom: 0.25rem; font-size: 0.9rem; line-height: 1.5; }
# .sec p   { font-size: 0.9rem; margin: 0.3rem 0; line-height: 1.55; }
# .grid2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# .grid3 { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# ...

# %% [markdown]
# ---
# ## Sección 10 — Investigación de mercado: encuesta

# %%
# @title
s10 = """
<div class='mj'>
  <div class='sec-num'>Sección 10</div>
  <div class='sec-title'>Investigación de mercado — Encuesta</div>
  <div class='sec-desc'>Instrumento de 12 preguntas para validar supuestos del modelo de negocio.
  Diseñado para aplicarse por WhatsApp o en persona en asambleas ejidales.</div>

  <div class='sec'>
    <h3>📋 Ficha técnica</h3>
    <div class='grid2'>
      <div><span class='tag tg'>Universo</span> Productores de limón Michoacán y Veracruz</div>
      <div><span class='tag tg'>Muestra objetivo</span> n=100 (piloto)</div>
      <div><span class='tag ta'>Canal</span> WhatsApp + aplicación en campo</div>
      <div><span class='tag ta'>Duración</span> 5–8 minutos</div>
      <div><span class='tag tt'>Muestreo</span> Conveniencia + bola de nieve ejidal</div>
      <div><span class='tag tt'>Escala</span> Likert 1–5 + opción múltiple</div>
    </div>
  </div>

  <div class='sec'>
    <h3>📝 Bloque A — Perfil del productor</h3>
    <div class='enc-q'><span class='qn'>P1.</span> ¿Cuántas hectáreas de limón cultiva aproximadamente?
      <em>(menos de 3 / 3 a 10 / 10 a 20 / más de 20)</em></div>
    <div class='enc-q'><span class='qn'>P2.</span> ¿Qué variedad produce principalmente?
      <em>(mexicano / persa / ambas / otra)</em></div>
    <div class='enc-q'><span class='qn'>P3.</span> ¿En qué municipio está su parcela principal?
      <em>(campo abierto)</em></div>
  </div>

  <div class='sec'>
    <h3>📝 Bloque B — Proceso de venta actual</h3>
    <div class='enc-q'><span class='qn'>P4.</span> ¿Cuánto tiempo antes de vender decide a quién y a qué precio vender su cosecha?
      <em>(el mismo día / 1–2 días antes / 1 semana antes / con contrato previo)</em></div>
    <div class='enc-q'><span class='qn'>P5.</span> ¿Cómo se entera del precio del limón antes de vender?
      <em>(el comprador me dice / grupo de WhatsApp / radio / periódico /
      no sé el precio hasta que llega el comprador)</em></div>
    <div class='enc-q'><span class='qn'>P6.</span> En una escala del 1 al 5, ¿qué tan satisfecho está con el precio que normalmente recibe?
      <em>(1=muy insatisfecho, 5=muy satisfecho)</em></div>
  </div>

  <div class='sec'>
    <h3>📝 Bloque C — Acceso a tecnología</h3>
    <div class='enc-q'><span class='qn'>P7.</span> ¿Tiene smartphone con acceso a internet?
      <em>(sí, siempre / sí, a veces / no tengo smartphone / tengo pero sin internet)</em></div>
    <div class='enc-q'><span class='qn'>P8.</span> ¿Usa WhatsApp regularmente?
      <em>(sí, todos los días / sí, algunas veces / no lo uso)</em></div>
  </div>

  <div class='sec'>
    <h3>📝 Bloque D — Disposición a usar Mercado Justo</h3>
    <div class='enc-q'><span class='qn'>P9.</span> Si existiera una herramienta que le avisara por WhatsApp si el precio del limón va a
      subir o bajar en los próximos 15 días, ¿la usaría?
      <em>(sí, definitivamente / probablemente sí / no sé / probablemente no / no)</em></div>
    <div class='enc-q'><span class='qn'>P10.</span> ¿Cuánto estaría dispuesto a pagar al mes por ese servicio si le ayuda a vender mejor?
      <em>(nada / hasta $50 / $50–$100 / $100–$200 / más de $200 MXN)</em></div>
    <div class='enc-q'><span class='qn'>P11.</span> ¿Qué le daría más confianza en una herramienta así?
      <em>(que la recomiende el FIRA o SADER / que la use alguien del ejido /
      que muestre casos reales / que sea gratis para probar)</em></div>
  </div>

  <div class='sec'>
    <h3>📝 Bloque E — Pregunta abierta</h3>
    <div class='enc-q'><span class='qn'>P12.</span> ¿Cuál es el mayor problema que tiene al momento de decidir cuándo y a quién vender su limón?
      <em>(respuesta abierta — se codificará por categorías temáticas)</em></div>
  </div>
</div>
"""
display(HTML(ESTILOS + s10))
# Out:
# <style>
# .mj { font-family: 'Segoe UI', sans-serif; max-width: 860px; margin: 0 auto; color: #1a1a1a; }
# .mj-hero { background: #EAF3DE; border-left: 5px solid #639922; border-radius: 8px;
#            padding: 1.2rem 1.5rem; margin-bottom: 1.2rem; }
# .mj-hero h2 { margin: 0 0 4px; color: #3B6D11; font-size: 1.3rem; }
# .mj-hero p  { margin: 0; color: #27500A; font-size: 0.88rem; }
# .sec { background: #fff; border: 1px solid #e0e0e0; border-radius: 10px;
#        padding: 1.2rem 1.4rem; margin-bottom: 1rem; }
# .sec h3 { margin: 0 0 0.7rem; font-size: 1rem; color: #3B6D11; }
# .sec ul  { margin: 0.3rem 0 0 1.1rem; padding: 0; }
# .sec li  { margin-bottom: 0.25rem; font-size: 0.9rem; line-height: 1.5; }
# .sec p   { font-size: 0.9rem; margin: 0.3rem 0; line-height: 1.55; }
# .grid2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# .grid3 { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 0.75rem; margin-bottom: 0.75rem; }
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title
# !find /content/drive -name "mercado_justo_mkt_digital.ipynb" 2>/dev/null

# %%
# !find /content/drive/MyDrive/pp_proyecto_limon -name "*.ipynb" 2>/dev/null
# Out:
# /content/drive/MyDrive/pp_proyecto_limon/K_means_lluvia_precios.ipynb
# /content/drive/MyDrive/pp_proyecto_limon/climaProduccionKIM.ipynb
# /content/drive/MyDrive/pp_proyecto_limon/Proyecto_semestre_5.ipynb
# /content/drive/MyDrive/pp_proyecto_limon/PP_Mercado_justo_limon.ipynb
# /content/drive/MyDrive/pp_proyecto_limon/mercado_justo_mkt_d.ipynb
